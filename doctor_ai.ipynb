# %%
import cohere
co = cohere.Client("<KEY>")

pream= '''
You are an expert medical assistant who extracts a comprehensive list of all possible diagnoses, comorbidies and abnormalities from patient discharge summaries. The discharge summaries are in markdown and may contain tables and additional metadata.
Give only diagnoses that can be inferred solely based on the information I have given - do not use any other information.
Bear in mind that the list of diagnoses you give will be used by medical coders later on so make the diagnoses as detailed and specific as possible given the available patient data.
Before finalising your answer check if you haven't missed any abnormal data points and hence any diagnoses that could be made based on them. If you did, add them to your response.
Start your answer with your list of diagnoses and do not generate any other text apart from the text needed to list the diagnoses.

For example, if the discharge summary mentions:
“Blood report:
min glucose: 103, max glucose: 278, avg glucose: 156.5, max inr: 2.1, max pt: 22.4, max ptt: 150, avg wbc: 13.8, max wbc: 14.1, max lactate: 5.9, max bun: 101, max creatinine: 5.8, avg bun: 38.15, avg creatinine: 2.78

Blood gas report:
3 h after admission the blood gas results from venous blood are: ph: 7.2

Imaging report:
__ y/o female with history of left total shoulder replacement
Chest X‐Ray Possible small right pleural effusion and Mild, bibasilar atelectasis... Lung volumes have slightly increased but areas of atelectasis are seen at both the left and the right lung bases

Microbiology tests:
24 h after admission the microbiology culture test MRSA SCREEN obtained via MRSA SCREEN identified POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS

Vitalsigns data from ICU:
max temperature: 38, min peripheral oxygen saturation: 70, max respiration rate: 29”

then your answer may be:

1: Methicillin resistant Staphylococcus aureus infection, site unspecified

2: Atelectasis

3: Pleural effusion, not elsewhere classified

4: Acidosis

5: Lactic acidosis

6: Acquired coagulation factor deficiency

7: Hyperglycemia, unspecified

8: Hypoxemia

9: Leukocytosis

10. Unspecified acute kidney failure:

11. Presence of left artificial shoulder joint

12: Unspecified septicemia

13: Septic shock

14: Acute respiratory failure, with hypoxia or hypercapnia

15: Type 2 diabetes mellitus with diabetic chronic kidney disease'''

msg = '''
<figure>

![](figures/0)

<!-- FigureContent="\+ Indraprastha Apollo Hospitals touching lives DELHI -" -->

</figure>


DISCHARGE SUMMARY
===

|||
| - | - |
| NAME | : MASTER.ANKIT BISWASH |
| UHID | : APD1.0000807307 |

|||
| - | - |
| Age/Sex | : 3 Year(s) Male |
| IPNO | : 208812 |

Date of Admission : 22-Nov-2008

Room/Ward

: 4159 (Recommended-Govt Of Delhi)

Date of Discharge :01-Apr-2009

Consultants

1\. Dr.A.K. Banerji NEUROSURGEON 2. Dr. Varindera Paul Singh NEUROSURGEON

Unit :NEUROSURGERY

DIAGNOSIS : Posterior Third Ventricle Ependymoma Hydrocephalus

HISTORY :- Right side facial weakness - 1 month Headache & vomiting - 20 days Difficulty in walking & frequent falls - 15 days CECT head revealed posterior third ventricle tumor with hydrocephalus

ON EXAMINATION

Child - sick BP - 100/60 mm Pupil - B/L 3 mm, reacting Fundus - B/L mild papilloedema Moving all four limbs

COURSE IN HOSPITAL :-

Pre-operatively was evaluated by Dr Nameet Jerath [Senior Consultant - Paediatric], and was taken up for surgery after his clearance.

OPERATIVE PROCEDURE: Midline suboccipital craniectomy, infratentorial-supracerebellar approach and microsurgical

Contd .. 2 ...

<figure>

![](figures/1)

<!-- FigureContent="P Joint Commission INTERNATIONAL" -->

</figure>


India's First Internationally Accredited Hospital Indraprastha Apollo Hospitals Sarita Vihar, Delhi - Mathura Road, New Delhi - 110 076 (INDIA) Tel. : 91-11- 26925858. 26925801, Fax : 91-11-26823629, Emergency Telephone No. : 1066. Website : www.apollohospdelhi.com
<figure>

![](figures/2)

<!-- FigureContent="Indraprastha Apollo Hospitals touching lives DELHI -" -->

</figure>


tumor decompression done under GA on 14.11.08.

Right parieto-occipital burrhole made and external ventricular drain inserted.

FINDINDS: Soft mildly vascular greyish tumor in posterior third ventricle.

HISTOPATHOLOGY: Ependymoma ( WHO - Gr II, Tanycytic type)

POST-OPERATIVE HOSPITAL STAY:

Was electively ventilated post-operativley in Neuro ICU. Next day weaned off from ventilator & extubated. NCCT head done on 15.11.08 ruled out any operative site haematoma with surgical changes and decrease in mass effect. Developed seizure followed by cardiac arrest. Recovered after resucitation & modification of anticonvulsant drugs. Kept on Midazolam infusion & gradually tapered off & shifted to Paed. ICU. NCCT head on 19.11.08, after removal of external ventricular drain revealed decrease in size of ventricles. Had copious throat secretions, so put on ventilatory support for 48 hour & then weaned off. Improve gradually & shifted out to Govt.ICU ward on 22.11.08. Dr. D.K.Mahajan [ Senior Consultant - Dermatology ] opinion taken for allergic skin lesion. Dr. S. Haldhar [Consultant -Radiation Oncology] opinion was taken for post operative adjuvant radiotherapy. Developed loose motion & fever, was managed with help of Paediatrician.

Contrast MRI brain done on 16.12.08 revealed surgical changes with persistent ventriculomegaly.

OPERATIVE PROCEDURE:

Right VP shunt [Medium Pressure - Pudenz] done under done under GA on 01.01.2009 FINDINGS: Clear CSF came in moderate pressure.

POST-OPERATIVE HOSPITAL STAY

Had mild improvement in the tonic posturing after the shunt surgery. IMRT was started in consultation with Dr Shikha Haldhar (Consultant Radiation Oncology). Had recurrent seizures with respiratory distress which was managed in consultation with Dr. N.Jerath (Senior Consultant,Pediatrics) and Dr. V.B.Gupta( Senior Consultant, Pediatric Neurology). Follow up NCCT head and MRI brain done revealed residual tumour in the region of posterior third ventricle with decreased ventricular size with increase in the bilateral subdural collections with no significant compression. Subdural tap was done and around 150cc of fluid aspirated, no neurological improvement seen after the procedure. Had recurrent episodes of laryngeal stridor. Dr. G. Raheja (Senior Consultant,ENT) was consulted who did tracheostomy on 23.03.2009. Follow up NCCT head done on 23.03.2009 revealed no change in the subdural collection.

COMMENTS:

Long term prognosis guarded. Needs regular follow up and neurorehabilitation.

CONDITION OF THE PATIENT AT THE TIME OF DISCHARGE :- BP - 100/60 mm

<!-- PageNumber="Contd .. 3 ..." -->

<figure>

![](figures/3)

<!-- FigureContent="Joint Commission INTERNATIONAL" -->

</figure>


India's First Internationally Accredited Hospital Indraprastha Apollo Hospitals Sarita Vihar, Delhi - Mathura Road, New Delhi - 110 076 (INDIA) Tel. : 91-11- 26925858, 26925801, Fax : 91-11-26823629, Emergency Telephone No. : 1066 Website : www.apollohospdelhi.com
<figure>

![](figures/4)

<!-- FigureContent="Indraprastha Apollo Hospitals touching lives - DELHI -" -->

</figure>


Afebrile Improving gaze paresis Opening eyes spontaneously, Tonic posturing present. Ryle's tube feed with oral supplement Wound healthy, Sutures removed On Tracheostomy

ADVICE ON DISCHARGE :-

DIET: Ryle's tube feeding 100 ml 2 hourly with oral supplement as tolerated

PHYSICAL ACTIVITY: Wheel chair mobilization

MEDICATIONS: Syp Augmentin 5ml thrice daily X 1 week Gardenal 60mgm twice daily X 1 month Syp Tegrital (100mgm /5ml) 4ml thrice daily X 1 month Frisium 5 mgm in morning and noon, and, 10mgm at bedtime X 1 month Tizan 2mgm thrice daily X 2 weeks Baclofen 7 mgm thrice daily X 2 weeks Diamox 250mgm half tablet twice daily X 2 weeks Rantac 25 mgm twice daily X 2 weeks Syp Visyneral 5ml daily X 2 weeks Asthalin and saline nebulization thrice daily X 1 month Crocin 10 ml SOS for fever/ headache Refresh eye drop both eye four hourly X 1 week

OTHERS:

Physiotherapy and mobilisation as advised Care of Tracheostomy and Ryle's tube

FOLLOW-UP: To follow up with Dr A K Banerji in Neurosciences OPD after 1 month Kindly confirm your appointment before coming. For appointments contact - 9910000409

For any medical problem contact Dr H S Sohal (9818535985)

Dr. A.K. Banerji SR.CONSULTANT NEUROSURGEON

Contd .. 4 ...

<figure>

![](figures/5)

<!-- FigureContent="Joint Commission INTERNATIONAL" -->

</figure>


India's First Internationally Accredited Hospital Indraprastha Apollo Hospitals Sarita Vihar, Delhi - Mathura Road, New Delhi - 110 076 (INDIA) Tel. : 91-11-26925858, 26925801, Fax : 91-11-26823629, Emergency Telephone No .: 1066 Website : www.apollohospdelhi.com

<!-- PageNumber="S2" -->
:selected: :selected: :selected: :selected:<figure>

![](figures/6)

<!-- FigureContent="Indraprastha Apollo Hospitals DELHI - touching lives" -->

</figure>


Dr. Varindera Paul Singh SR.CONSULTANT NEUROSURGEON

<figure>

![](figures/7)

<!-- FigureContent="30/1/09" -->

</figure>


\*HSS

Registrar/Resident/C.M.O

Date

: 30-Mar-2009 10:27 AM.

<figure>

![](figures/8)

<!-- FigureContent="Joint Commission INTERNATIONAL" -->

</figure>


India's First Internationally Accredited Hospital Indraprastha Apollo Hospitals Sarita Vihar, Delhi - Mathura Road, New Delhi - 110 076 (INDIA) Tel. : 91-11- 26925858, 26925801, Fax : 91-11-26823629, Emergency Telephone No. : 1066 Website : www.apollohospdelhi.com

<!-- PageNumber="S .-" -->
'''
response = co.chat(message=msg,
                   model="command-r-plus",
                   preamble=pream)
print(response.text)
# Out:
# <>:60: SyntaxWarning: invalid escape sequence '\+'
# <>:60: SyntaxWarning: invalid escape sequence '\+'
# /var/folders/nz/v_j2h2qx7s19_9mnwnz7489m0000gn/T/ipykernel_46485/9179200.py:60: SyntaxWarning: invalid escape sequence '\+'
#   msg = '''
# 1: Posterior third ventricle ependymoma, WHO Grade II, Tanycytic type
#
# 2: Hydrocephalus
#
# 3: Right side facial weakness
#
# 4: Headache
#
# 5: Vomiting
#
# 6: Gait abnormality
#
# 7: Frequent falls
#
# 8: Papilledema
#
# 9: Tonic-clonic seizures
#
# 10: Cardiac arrest
#
# 11: Ventricular dilatation
#
# 12: Diarrhea
#
# 13: Fever
#
# 14: Gaze paresis
#
# 15: Subdural effusion
#
# 16: Laryngeal stridor
#
# 17: Allergic skin lesions

# %%
diagnosis = response.text.split('\n')
list_of_diagnosis = [d for d in response.text.split('\n') if d != '']
# remove numbers from the list
list_of_diagnosis = [d.split(': ')[1] for d in list_of_diagnosis]
list_of_diagnosis
# Out:
# ['Posterior third ventricle ependymoma, WHO Grade II, Tanycytic type',
#  'Hydrocephalus',
#  'Right side facial weakness',
#  'Headache',
#  'Vomiting',
#  'Gait abnormality',
#  'Frequent falls',
#  'Papilledema',
#  'Tonic-clonic seizures',
#  'Cardiac arrest',
#  'Ventricular dilatation',
#  'Diarrhea',
#  'Fever',
#  'Gaze paresis',
#  'Subdural effusion',
#  'Laryngeal stridor',
#  'Allergic skin lesions']

# %%
# retrieve codes of the most similar 
data = "/Users/aziz/Code/hackathons/cohere_london_5_2024/data/ICD11To10MapToOneCategory.xlsx - 11To10MapToOneCategory.csv"
# read csv file
import pandas as pd
df = pd.read_csv(data)

# %%
df
# Out:
#                              Linearization (release) URI icd11Code  \
# 0      http://id.who.int/icd/release/11/2024-01/mms/1...        01
# 1      http://id.who.int/icd/release/11/2024-01/mms/5...       NaN
# 2      http://id.who.int/icd/release/11/2024-01/mms/1...       NaN
# 3      http://id.who.int/icd/release/11/2024-01/mms/2...      1A00
# 4      http://id.who.int/icd/release/11/2024-01/mms/4...      1A01
# ...                                                  ...       ...
# 17903  http://id.who.int/icd/release/11/2024-01/mms/4...      RA22
# 17904  http://id.who.int/icd/release/11/2024-01/mms/2...      RA23
# 17905  http://id.who.int/icd/release/11/2024-01/mms/1...      RA24
# 17906  http://id.who.int/icd/release/11/2024-01/mms/1...      RA25
# 17907  http://id.who.int/icd/release/11/2024-01/mms/1...      RA26
#
#        icd11Chapter                                       icd11Title  \
# 0                 1         Certain infectious or parasitic diseases
# 1                 1  Gastroenteritis or colitis of infectious origin
# 2                 1                  Bacterial intestinal infections
# 3                 1                                          Cholera
# 4                 1         Intestinal infection due to other Vibrio
# ...             ...                                              ...
# 17903            25                       National emergency code 03
# 17904            25                       National emergency code 04
# 17905            25                       National emergency code 05
# 17906            25                       National emergency code 06
# 17907            25                       National emergency code 07
#
#       icd10Code icd10Chapter                                   icd10Title  \
# 0             I            I    Certain infectious and parasitic diseases
# 1             I            I    Certain infectious and parasitic diseases
# 2         A04.9            I  Bacterial intestinal infection, unspecified
# 3         A00.9            I                         Cholera, unspecified
# 4           A04            I        Other bacterial intestinal infections
# ...         ...          ...                                          ...
# 17903      XXII         XXII                   Codes for special purposes
# 17904      XXII         XXII                   Codes for special purposes
# 17905      XXII         XXII                   Codes for special purposes
# 17906      XXII         XXII                   Codes for special purposes
# 17907      XXII         XXII                   Codes for special purposes
#
#        21/1/2024
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 17903        NaN
# 17904        NaN
# 17905        NaN
# 17906        NaN
# 17907        NaN
#
# [17908 rows x 8 columns]

# %% [markdown]
# # Create RAG

# %%
import torch
from langchain_community.vectorstores import Chroma
from langchain.docstore.document import Document
from langchain_community.embeddings import (
    OpenAIEmbeddings,
    OllamaEmbeddings,
    HuggingFaceEmbeddings,
)

def embedding_func(selected_embedding: str = "HuggingFaceEmbeddings"):
    """
    Create and return an embedding object based on the selected embedding type.
    This function supports the creation of different embedding representations
    for text data using pre-trained models from OpenAI, Ollama, and HuggingFace.
    Parameters:
    - selected_embedding (str): The type of embedding to use. Supported values are:
        - "OpenAIEmbeddings": Use embeddings from OpenAI.
        - "OllamaEmbeddings": Use embeddings from Ollama with the "nomic-ai" model.
        - "HuggingFaceEmbeddings": Use embeddings from HuggingFace with the "BAAI/bge-small-en-v1.5" model.
        - "HuggingFaceBgeEmbeddings": Use BGE embeddings from HuggingFace with a default model. (not used)
    Returns:
    - An instance of the selected embedding class.
    References:
    - https://github.com/huggingface/text-embeddings-inference?tab=readme-ov-file#get-started
    - https://huggingface.co/BAAI/bge-m3
    - https://ollama.com/library/nomic-embed-text
    """
    if selected_embedding == "OpenAIEmbeddings":
        embedding_func = OpenAIEmbeddings()
    elif selected_embedding == "OllamaEmbeddings":
        embedding_func = OllamaEmbeddings(model="nomic-embed-text:v1.5")
    elif selected_embedding == "HuggingFaceEmbeddings":
        device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
        embedding_func = HuggingFaceEmbeddings(model_name="BAAI/bge-small-en-v1.5", model_kwargs={"device": device})
    else:
      raise ValueError("uknown type")
    return embedding_func


def create_langchain_documents(df, target_col):
    """create langchain documents from data"""
    cols = df.columns
    return df.apply(lambda row: Document(page_content=row[target_col], metadata=row[cols].to_dict()), axis=1).tolist()


def create_rag(df):
    target_col = "icd11Title"

    # create documents from sample symptoms
    docs = create_langchain_documents(df, target_col)

    _embedding_func = embedding_func()
    vectorstore = Chroma.from_documents(documents=docs, embedding=_embedding_func)

    return df, docs, vectorstore

# %%
df.shape
# Out:
# (17908, 8)

# %%
# %%time
df, docs, vectorstore = create_rag(df)
# Out:
# /Users/aziz/Code/hackathons/cohere_london_5_2024/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# CPU times: user 41.2 s, sys: 5.71 s, total: 47 s
# Wall time: 36.3 s

# %% [markdown]
# # Re-ranking

# %%
def rerank_results(query: str, docs: pd.DataFrame, top_n: int):
    """ 
    Re-rank DB search results using Cohere's re-rank model.

    Args:
        query (str): user's query
        docs (pd.DataFrame): dataframe of documents with 'Disease' and 'Symptoms' columns. The results of the search 'retrieval'.
        top_n (int): number of results to return

    from https://docs.cohere.com/docs/rerank-2

    Relevance score: the higher the more relevant. (see: https://docs.cohere.com/docs/reranking-2)
    """

    COHERE_API_KEY = "PA1n171tXRwFtkSw3pJvNNpUYUzvLx05SiUqKtwx" # TODO: move to .env

    co = cohere.Client(COHERE_API_KEY)

    # concat disease and symptoms columns from dataframe
    # docs = docs.apply(lambda x: f"{x['Label']} {x['vDocument']}", axis=1).tolist()
    docs = docs.apply(lambda x: f"{x['icd11Code']} {x['icd11Title']}", axis=1).tolist()
    
    # choose_re-rank model
    model = "rerank-english-v3.0"

    response = co.rerank(
        model = model,
        query = query,
        documents = docs,
        top_n = top_n,
    )
    
    results = response.results
    
    # index re-map to original docs
    # and flatten results
    flattened = [Document(page_content=f"source_doc_index: {r.index}", metadata={"relevance_score": r.relevance_score, "ranked_doc": docs[r.index]}) for r in results]

    # convert results to dataframe
    df = pd.DataFrame([d.metadata for d in flattened])
    
    return df

# %% [markdown]
# # Search Disease Code from the diagnosis input

# %%
from IPython.display import display
for diagnosis in list_of_diagnosis:
    
    # semantic search (Vector store search)
    result = vectorstore.similarity_search_with_score(diagnosis, k=1000)
    result_df = pd.DataFrame([d.metadata for d, score in result])

    # Re-rank search results
    re_ranked_results = rerank_results(query=diagnosis, docs=result_df, top_n=10)

    # re-rank with cohere
    print(f"Diagnosis: {diagnosis}")
    display(result_df[:10])
    display(re_ranked_results)
# Out:
# Diagnosis: Posterior third ventricle ependymoma, WHO Grade II, Tanycytic type
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...           II   C69-C72
# 1  http://id.who.int/icd/release/11/2024-01/mms/9...           II   C69-C72
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...           II   C69-C72
# 3  http://id.who.int/icd/release/11/2024-01/mms/9...           II   C69-C72
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           II   C69-C72
# 5  http://id.who.int/icd/release/11/2024-01/mms/4...           II   C69-C72
# 6  http://id.who.int/icd/release/11/2024-01/mms/9...           II   C69-C72
# 7  http://id.who.int/icd/release/11/2024-01/mms/9...           II   C69-C72
# 8  http://id.who.int/icd/release/11/2024-01/mms/6...           II   C69-C72
# 9  http://id.who.int/icd/release/11/2024-01/mms/5...         XVII   Q20-Q28
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0  Malignant neoplasms of eye, brain and other pa...             2   2A00.1Y
# 1  Malignant neoplasms of eye, brain and other pa...             2    2A00.4
# 2  Malignant neoplasms of eye, brain and other pa...             2   2A00.1Z
# 3  Malignant neoplasms of eye, brain and other pa...             2   2A00.2Y
# 4  Malignant neoplasms of eye, brain and other pa...             2    2A00.1
# 5  Malignant neoplasms of eye, brain and other pa...             2   2A00.0Y
# 6  Malignant neoplasms of eye, brain and other pa...             2   2A00.2Z
# 7  Malignant neoplasms of eye, brain and other pa...             2    2A00.2
# 8  Malignant neoplasms of eye, brain and other pa...             2    2A00.5
# 9  Congenital malformations of the circulatory sy...            20    LA88.Z
#
#                                           icd11Title
# 0         Other specified embryonal tumours of brain
# 1                         Astroblastoma of the brain
# 2            Embryonal tumours of brain, unspecified
# 3  Other specified tumours of neuroepithelial tis...
# 4                         Embryonal tumours of brain
# 5                   Other specified gliomas of brain
# 6  Tumours of neuroepithelial tissue of brain, un...
# 7         Tumours of neuroepithelial tissue of brain
# 8  Primary neoplasm of brain of unknown or unspec...
# 9  Congenital anomaly of a ventricle or the ventr...
#    relevance_score                                         ranked_doc
# 0         0.000181  KA82.2 Intraventricular nontraumatic haemorrha...
# 1         0.000143  KA82.1 Intraventricular nontraumatic haemorrha...
# 2         0.000140  LA87 Congenital anomaly of an atrioventricular...
# 3         0.000115  LA87.Z Congenital anomaly of an atrioventricul...
# 4         0.000115  BC63.10 High-grade second degree atrioventricu...
# 5         0.000111                                EK70.3 Hidrocystoma
# 6         0.000103  KA82.3 Intraventricular nontraumatic haemorrha...
# 7         0.000099  LA87.Y Other specified congenital anomaly of a...
# 8         0.000080        KA42.1 Cephalohaematoma due to birth injury
# 9         0.000075                2A01.0Y Other specified meningiomas
# Diagnosis: Hydrocephalus
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/5...           VI       G94
# 1  http://id.who.int/icd/release/11/2024-01/mms/5...           VI       G94
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...         XVII       Q03
# 3  http://id.who.int/icd/release/11/2024-01/mms/9...          XVI       P91
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G91.2
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...         XVII       Q03
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G91.1
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G91.0
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G91.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/1...         XVII     Q03.0
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0  Other disorders of brain in diseases classifie...             8      8D64
# 1  Other disorders of brain in diseases classifie...             8    8D64.Z
# 2                           Congenital hydrocephalus            20      LA04
# 3   Other disturbances of cerebral status of newborn            19      KB05
# 4                      Normal-pressure hydrocephalus             8   8D64.04
# 5                           Congenital hydrocephalus            20    LA04.Z
# 6                          Obstructive hydrocephalus             8   8D64.10
# 7                        Communicating hydrocephalus             8    8D64.0
# 8                        Communicating hydrocephalus             8   8D64.0Y
# 9               Malformations of aqueduct of Sylvius            20    LA04.0
#
#                                           icd11Title
# 0                                      Hydrocephalus
# 1                         Hydrocephalus, unspecified
# 2                           Congenital hydrocephalus
# 3                             Neonatal hydrocephalus
# 4                      Normal-pressure hydrocephalus
# 5              Congenital hydrocephalus, unspecified
# 6      Hydrocephalus due to structural malformations
# 7                        Communicating hydrocephalus
# 8        Other specified communicating hydrocephalus
# 9  Hydrocephalus with stenosis of the aqueduct of...
#    relevance_score                                         ranked_doc
# 0         0.204183                            LA05.62 Hydranencephaly
# 1         0.101411                  8D64.Z Hydrocephalus, unspecified
# 2         0.059319  8B24.Z Hypoxic-ischaemic encephalopathy, unspe...
# 3         0.053601                 8B22.8 Hypertensive encephalopathy
# 4         0.052231  NA07.45 Focal haematoma or haemorrhage of cere...
# 5         0.044349       LA04.Z Congenital hydrocephalus, unspecified
# 6         0.041852  nan Disorders of cerebrospinal fluid pressure ...
# 7         0.041462  MC2Y Other specified symptoms, signs or clinic...
# 8         0.038902  LA04.0 Hydrocephalus with stenosis of the aque...
# 9         0.036152  8D6Z Disorders of cerebrospinal fluid pressure...
# Diagnosis: Right side facial weakness
#                          Linearization (release) URI icd10Chapter   icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/3...         XVII       Q67.0
# 1  http://id.who.int/icd/release/11/2024-01/mms/5...          XIX       S04.5
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...           VI         G51
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...           VI         G51
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           IX         I50
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...           VI       G51.8
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...          NaN  No Mapping
# 7  http://id.who.int/icd/release/11/2024-01/mms/2...           XI         K09
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII       R52.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/2...           XI         K09
#
#                                        icd10Title  icd11Chapter icd11Code  \
# 0                                Facial asymmetry            20      LA52
# 1                          Injury of facial nerve            22    NA04.6
# 2                          Facial nerve disorders             8    8B88.Z
# 3                          Facial nerve disorders             8      8B88
# 4                                   Heart failure            11      BD13
# 5                 Other disorders of facial nerve             8    8B88.Y
# 6                                             NaN             8      8A85
# 7  Cysts of oral region, not elsewhere classified            13    DA05.Z
# 8                                      Acute pain            21    MG31.0
# 9  Cysts of oral region, not elsewhere classified            13      DA05
#
#                                           icd11Title
# 0                                   Facial asymmetry
# 1                             Injury of facial nerve
# 2             Disorders of facial nerve, unspecified
# 3                          Disorders of facial nerve
# 4                          Right ventricular failure
# 5          Other specified disorders of facial nerve
# 6  Painful cranial neuropathies or other facial p...
# 7   Cysts of oral or facial-neck region, unspecified
# 8   Acute pain in the face, not elsewhere classified
# 9                Cysts of oral or facial-neck region
#    relevance_score                                         ranked_doc
# 0         0.002059                     8B88 Disorders of facial nerve
# 1         0.001495   8B88.Y Other specified disorders of facial nerve
# 2         0.001455  8A01.12 Chorea due to Dentatorubral pallidoluy...
# 3         0.001269  DA0Z Diseases or disorders of orofacial comple...
# 4         0.000876      8B88.Z Disorders of facial nerve, unspecified
# 5         0.000853                            8B88.2 Hemifacial spasm
# 6         0.000826  DA0Y Other specified diseases or disorders of ...
# 7         0.000820  MB23.Y Other specified symptoms and signs invo...
# 8         0.000744                 8B82 Disorders of trigeminal nerve
# 9         0.000729  DA0F Sensory disturbances affecting orofacial ...
# Diagnosis: Headache
#                          Linearization (release) URI icd10Chapter   icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/6...           VI         G43
# 1  http://id.who.int/icd/release/11/2024-01/mms/2...          NaN  No Mapping
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...           VI         G44
# 3  http://id.who.int/icd/release/11/2024-01/mms/9...           VI       G44.3
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           VI         G44
# 5  http://id.who.int/icd/release/11/2024-01/mms/3...        XVIII         R52
# 6  http://id.who.int/icd/release/11/2024-01/mms/6...           VI         G43
# 7  http://id.who.int/icd/release/11/2024-01/mms/6...        XVIII         R52
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII       R52.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/2...           VI         G44
#
#                         icd10Title  icd11Chapter icd11Code  \
# 0                         Migraine             8      8A80
# 1                              NaN             8       NaN
# 2         Other headache syndromes             8    8A81.Z
# 3  Chronic post-traumatic headache             8    8A84.0
# 4         Other headache syndromes             8      8A81
# 5   Pain, not elsewhere classified            21   MG30.67
# 6                         Migraine             8    8A80.Z
# 7   Pain, not elsewhere classified            21       NaN
# 8                       Acute pain            21    MG31.1
# 9         Other headache syndromes             8      8A84
#
#                                           icd11Title
# 0                                           Migraine
# 1                                 Headache disorders
# 2                 Tension-type headache, unspecified
# 3  Acute headache associated with traumatic injur...
# 4                              Tension-type headache
# 5  Chronic headache associated with a substance o...
# 6                              Migraine, unspecified
# 7                                               Pain
# 8           Acute headache, not elsewhere classified
# 9                                 Secondary headache
#    relevance_score                                         ranked_doc
# 0         0.084342  8A84.0 Acute headache associated with traumati...
# 1         0.081666  8A84.1 Persistent headache associated with tra...
# 2         0.055413  MG30.63 Headache or orofacial pain associated ...
# 3         0.024330  MG30.64 Chronic headache or orofacial pain ass...
# 4         0.018440  MG30.65 Chronic headache or orofacial pain ass...
# 5         0.010735  NA0A.10 Strain or sprain of muscle, fascia or ...
# 6         0.007317            MB4D Headache, not elsewhere classified
# 7         0.007177               8A8Z Headache disorders, unspecified
# 8         0.006615  NA03.Y Dislocation or sprain of other specifie...
# 9         0.005598                    nan Disorders of cranial nerves
# Diagnosis: Vomiting
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/4...        XVIII       R11
# 1  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII       R11
# 2  http://id.who.int/icd/release/11/2024-01/mms/6...        XVIII       R11
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...          XVI     P92.0
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...            X     J69.0
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...          XVI     P92.0
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...           XV       O21
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...           XV       O21
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...           XI     K91.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/1...          XVI     P92.0
#
#                                     icd10Title  icd11Chapter icd11Code  \
# 0                          Nausea and vomiting            21    MD90.1
# 1                          Nausea and vomiting            21    MD90.0
# 2                          Nausea and vomiting            21      MD90
# 3                          Vomiting in newborn            19      KD3C
# 4            Pneumonitis due to food and vomit            12    CA71.0
# 5                          Vomiting in newborn            19    KD3C.Y
# 6              Excessive vomiting in pregnancy            18      JA60
# 7              Excessive vomiting in pregnancy            18    JA60.Z
# 8  Vomiting following gastrointestinal surgery            13      DE10
# 9                          Vomiting in newborn            19    KD3C.Z
#
#                                        icd11Title
# 0                                        Vomiting
# 1                                          Nausea
# 2                              Nausea or vomiting
# 3                             Vomiting in newborn
# 4  Pneumonitis due to inhalation of food or vomit
# 5             Other specified vomiting in newborn
# 6                 Excessive vomiting in pregnancy
# 7    Excessive vomiting in pregnancy, unspecified
# 8     Vomiting following gastrointestinal surgery
# 9                Vomiting in newborn, unspecified
#    relevance_score                                         ranked_doc
# 0         0.113187  MB23.A Excessive crying of child, adolescent, ...
# 1         0.090897                                    MD90.1 Vomiting
# 2         0.087876  JA60.Y Other specified excessive vomiting in p...
# 3         0.062217  JA60.Z Excessive vomiting in pregnancy, unspec...
# 4         0.038538  KB26.3 Neonatal aspiration of milk or regurgit...
# 5         0.032161  CA71.0 Pneumonitis due to inhalation of food o...
# 6         0.022890                        DD93.0 Infant regurgitation
# 7         0.019985  4A83.Y Other specified allergic or hypersensit...
# 8         0.018511  JB0C.0 Aspiration pneumonitis due to anaesthes...
# 9         0.017111               JA60 Excessive vomiting in pregnancy
# Diagnosis: Gait abnormality
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII       R26
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII       R26
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII     R26.8
# 3  http://id.who.int/icd/release/11/2024-01/mms/2...        XVIII     R26.1
# 4  http://id.who.int/icd/release/11/2024-01/mms/4...        XVIII     R25.0
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...            V     F48.9
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...            V     F48.9
# 7  http://id.who.int/icd/release/11/2024-01/mms/6...        XVIII       R25
# 8  http://id.who.int/icd/release/11/2024-01/mms/4...        XVIII     R26.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII     R29.3
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0                 Abnormalities of gait and mobility            21      MB44
# 1                 Abnormalities of gait and mobility            21    MB44.Z
# 2  Other and unspecified abnormalities of gait an...            21    MB44.Y
# 3                                     Paralytic gait            21    MB44.1
# 4                            Abnormal head movements            21    MB46.1
# 5                     Neurotic disorder, unspecified             6    6B60.7
# 6                     Neurotic disorder, unspecified             6    6B60.7
# 7                     Abnormal involuntary movements            21      MB46
# 8                                        Ataxic gait            21    MB44.0
# 9                                   Abnormal posture            21    MB47.1
#
#                                           icd11Title
# 0                 Abnormalities of gait and mobility
# 1    Abnormalities of gait and mobility, unspecified
# 2  Other specified abnormalities of gait and mobi...
# 3                                     Paralytic gait
# 4                            Abnormal head movements
# 5  Dissociative neurological symptom disorder, wi...
# 6  Dissociative neurological symptom disorder, wi...
# 7                     Abnormal involuntary movements
# 8                                        Ataxic gait
# 9                                   Abnormal posture
#    relevance_score                                         ranked_doc
# 0         0.929184  MB44.Z Abnormalities of gait and mobility, uns...
# 1         0.899828            MB44 Abnormalities of gait and mobility
# 2         0.217670  MB44.Y Other specified abnormalities of gait a...
# 3         0.003945                             nan Movement disorders
# 4         0.003538           BC63.Z Conduction disorders, unspecified
# 5         0.003197                          BC63 Conduction disorders
# 6         0.001472                    nan Disorders of cranial nerves
# 7         0.001341  6B60.7 Dissociative neurological symptom disor...
# 8         0.001341  6B60.7 Dissociative neurological symptom disor...
# 9         0.001226  MB47.Z Abnormality of tonus and reflex, unspec...
# Diagnosis: Frequent falls
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII     R29.6
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...           XX   W00-W19
# 2  http://id.who.int/icd/release/11/2024-01/mms/4...           XX   W00-W19
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...           XX   W00-W19
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           XX   X60-X84
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...           XX   W00-W19
# 6  http://id.who.int/icd/release/11/2024-01/mms/2...           XX   X60-X84
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...           XX   X60-X84
# 8  http://id.who.int/icd/release/11/2024-01/mms/4...        XVIII       R35
# 9  http://id.who.int/icd/release/11/2024-01/mms/1...           XX       X80
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0         Tendency to fall, not elsewhere classified            21    MB47.C
# 1                                              Falls            23       NaN
# 2                                              Falls            23      PA60
# 3                                              Falls            23      PA61
# 4                              Intentional self-harm            23       NaN
# 5                                              Falls            23      PA6Z
# 6                              Intentional self-harm            23      PC30
# 7                              Intentional self-harm            23      PC3Z
# 8                                           Polyuria            21    MF50.0
# 9  Intentional self-harm by jumping from a high p...            23      PC31
#
#                                           icd11Title
# 0                                   Tendency to fall
# 1                                 Unintentional fall
# 2  Unintentional fall on the same level or from l...
# 3  Unintentional fall from a height of 1 metre or...
# 4              Intentional self-harm by fall or jump
# 5         Unintentional fall from unspecified height
# 6  Intentional self-harm by fall or jump on same ...
# 7  Intentional self-harm by fall or jump, unspeci...
# 8                               Frequent micturition
# 9  Intentional self-harm by fall or jump from a h...
#    relevance_score                                         ranked_doc
# 0         0.002027  8D42 Neurological disorders due to overweight ...
# 1         0.001623  PC31 Intentional self-harm by fall or jump fro...
# 2         0.001579  PC30 Intentional self-harm by fall or jump on ...
# 3         0.001086  PG51 Fall or jump of undetermined intent from ...
# 4         0.000814  PE01 Assault by causing a fall or jump from a ...
# 5         0.000688  PG50 Fall or jump of undetermined intent on th...
# 6         0.000551                GA20.10 Frequent menstrual bleeding
# 7         0.000519  nan Injuries to the abdomen, lower back, lumba...
# 8         0.000462  8A84.1 Persistent headache associated with tra...
# 9         0.000431  PA40.1 Unintentional water transport injury ev...
# Diagnosis: Papilledema
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/3...          VII     H47.1
# 1  http://id.who.int/icd/release/11/2024-01/mms/3...          VII       H10
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII     R60.9
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...           XI     K14.3
# 4  http://id.who.int/icd/release/11/2024-01/mms/3...          VII       H10
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...           XI     K13.6
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...            X   J60-J70
# 7  http://id.who.int/icd/release/11/2024-01/mms/7...         VIII     H70.2
# 8  http://id.who.int/icd/release/11/2024-01/mms/6...        XVIII     R60.1
# 9  http://id.who.int/icd/release/11/2024-01/mms/9...        XVIII       R46
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0                          Papilloedema, unspecified             9   9C40.A0
# 1                                     Conjunctivitis             9    9A60.0
# 2                                Oedema, unspecified            14    EF02.2
# 3                     Hypertrophy of tongue papillae            13    DA03.4
# 4                                     Conjunctivitis             9   9A60.0Z
# 5              Irritative hyperplasia of oral mucosa            13   DA01.40
# 6               Lung diseases due to external agents            12       NaN
# 7                                         Petrositis            10    AB11.2
# 8                                 Generalized oedema            21   MG29.10
# 9  Symptoms and signs involving appearance and be...            21    MB23.9
#
#                                    icd11Title
# 0                                Papilloedema
# 1                    Papillary conjunctivitis
# 2                                   Lipoedema
# 3              Hypertrophy of tongue papillae
# 4       Papillary conjunctivitis, unspecified
# 5        Papillary hyperplasia of oral mucosa
# 6                                 Pneumonitis
# 7                                  Petrositis
# 8  Oedema due to increased capillary pressure
# 9                                   Echolalia
#    relevance_score                                         ranked_doc
# 0         0.622459                               9C40.A0 Papilloedema
# 1         0.017309                          EK50.00 Papular urticaria
# 2         0.015248   9A60.0Y Other specified papillary conjunctivitis
# 3         0.012194    BD93.13 Lymphoedema due to lymphatic filariasis
# 4         0.007786    BD93.10 Lymphoedema due to venous insufficiency
# 5         0.006931                              9A78.2 Corneal oedema
# 6         0.006564  EB01.Z Inducible urticaria and angioedema, uns...
# 7         0.006438             9A60.00 Giant papillary conjunctivitis
# 8         0.004886  CA81.1 Pulmonary oedema due to chemicals, gase...
# 9         0.004039        2F00.1 Recurrent respiratory papillomatosis
# Diagnosis: Tonic-clonic seizures
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G40.6
# 1  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII       R56
# 2  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII       R56
# 3  http://id.who.int/icd/release/11/2024-01/mms/3...        XVIII       R56
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G41.2
# 5  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII     R56.8
# 6  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII       R56
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII       R56
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...           VI     G40.8
# 9  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII     R56.0
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0  Grand mal seizures, unspecified (with or witho...             8    8A68.4
# 1              Convulsions, not elsewhere classified             8    8A68.6
# 2              Convulsions, not elsewhere classified             8      8A68
# 3              Convulsions, not elsewhere classified             8    8A68.7
# 4                 Complex partial status epilepticus             8      8A67
# 5                  Other and unspecified convulsions             8    8A68.Y
# 6              Convulsions, not elsewhere classified             8    8A68.Z
# 7              Convulsions, not elsewhere classified             8    8A68.5
# 8                                     Other epilepsy             8      8A6Y
# 9                                Febrile convulsions             8   8A63.01
#
#                              icd11Title
# 0      Generalised tonic-clonic seizure
# 1             Generalised tonic seizure
# 2                     Types of seizures
# 3            Generalised atonic seizure
# 4             Acute repetitive seizures
# 5       Other specified type of seizure
# 6          Type of seizure, unspecified
# 7         Generalised myoclonic seizure
# 8  Other specified epilepsy or seizures
# 9              Complex febrile seizures
#    relevance_score                                         ranked_doc
# 0         0.871146            8A68.4 Generalised tonic-clonic seizure
# 1         0.612483   8A61.22 Epilepsy with myoclonic-astatic seizures
# 2         0.159741               8A68.5 Generalised myoclonic seizure
# 3         0.136954                8A61.30 Juvenile myoclonic epilepsy
# 4         0.098079                  8A68.7 Generalised atonic seizure
# 5         0.096706             8A61.41 Progressive myoclonic epilepsy
# 6         0.072637                   8A68.6 Generalised tonic seizure
# 7         0.040012  8A61.12 Epilepsy of infancy with migrating foc...
# 8         0.027429                             8A68 Types of seizures
# 9         0.024988   8A61.32 Benign adult familial myoclonus epilepsy
# Diagnosis: Cardiac arrest
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/3...           IX       I46
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I46.9
# 2  http://id.who.int/icd/release/11/2024-01/mms/3...           IX       I46
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I46.9
# 4  http://id.who.int/icd/release/11/2024-01/mms/5...           IX     I46.9
# 5  http://id.who.int/icd/release/11/2024-01/mms/2...           IX       I46
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII     R09.2
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I46.9
# 8  http://id.who.int/icd/release/11/2024-01/mms/6...          XIX       T71
# 9  http://id.who.int/icd/release/11/2024-01/mms/4...        XVIII       R55
#
#                     icd10Title  icd11Chapter icd11Code  \
# 0               Cardiac arrest            21      MC82
# 1  Cardiac arrest, unspecified            21    MC82.1
# 2               Cardiac arrest            21    MC82.Z
# 3  Cardiac arrest, unspecified            21    MC82.2
# 4  Cardiac arrest, unspecified            21    MC82.3
# 5               Cardiac arrest            21    MC82.4
# 6           Respiratory arrest            21      MD33
# 7  Cardiac arrest, unspecified            21    MC82.0
# 8                 Asphyxiation            22      NF05
# 9         Syncope and collapse            21    MG45.0
#
#                                           icd11Title
# 0                                     Cardiac arrest
# 1                         Bradycardic cardiac arrest
# 2                        Cardiac arrest, unspecified
# 3                           Asystolic cardiac arrest
# 4  Cardiac arrest with pulseless electrical activity
# 5                             Cardiopulmonary arrest
# 6                                 Respiratory arrest
# 7  Ventricular tachycardia and fibrillation cardi...
# 8                                       Asphyxiation
# 9                                    Cardiac syncope
#    relevance_score                                         ranked_doc
# 0         0.573678                 MC82.Z Cardiac arrest, unspecified
# 1         0.421254  MC82.3 Cardiac arrest with pulseless electrica...
# 2         0.210604                                MC82 Cardiac arrest
# 3         0.095856  PK81.E Cardiopulmonary resuscitation associate...
# 4         0.067424                      MC82.4 Cardiopulmonary arrest
# 5         0.049497  MC82.0 Ventricular tachycardia and fibrillatio...
# 6         0.029760                  MC82.1 Bradycardic cardiac arrest
# 7         0.025565  BA60.9 Cardiogenic shock, unrelated to mechani...
# 8         0.003751                    MC82.2 Asystolic cardiac arrest
# 9         0.002541                           MG40.0 Cardiogenic shock
# Diagnosis: Ventricular dilatation
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I49.3
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I49.8
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I42.0
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I49.0
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I47.2
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...           XI   K90-K93
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...           IX     I97.8
# 7  http://id.who.int/icd/release/11/2024-01/mms/6...         XVII     Q21.0
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...           IX        IX
# 9  http://id.who.int/icd/release/11/2024-01/mms/6...           IX       I99
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0               Ventricular premature depolarization            11      BC70
# 1                Other specified cardiac arrhythmias            11      BC71
# 2                             Dilated cardiomyopathy            11    BC43.0
# 3               Ventricular fibrillation and flutter            11    BC71.1
# 4                            Ventricular tachycardia            11    BC71.0
# 5             Other diseases of the digestive system            21    ME24.6
# 6  Other postprocedural disorders of circulatory ...            11      BE19
# 7                          Ventricular septal defect            20    LA88.4
# 8                 Diseases of the circulatory system            11       NaN
# 9  Other and unspecified disorders of circulatory...            11      BC41
#
#                                icd11Title
# 0    Ventricular premature depolarization
# 1             Ventricular tachyarrhythmia
# 2                  Dilated cardiomyopathy
# 3                Ventricular fibrillation
# 4                 Ventricular tachycardia
# 5             Digestive system dilatation
# 6  Postprocedural ventricular abnormality
# 7               Ventricular septal defect
# 8          Ventricular rhythm disturbance
# 9        Acquired ventricular abnormality
#    relevance_score                                         ranked_doc
# 0         0.092196  BA60.2 Ventricular aneurysm as current complic...
# 1         0.005002                 ME24.6 Digestive system dilatation
# 2         0.002208  LA88.Y Other specified congenital anomaly of a...
# 3         0.001972  LA85.23 Double outlet right ventricle with sub...
# 4         0.001927  MC82.0 Ventricular tachycardia and fibrillatio...
# 5         0.001839  LA85.22 Double outlet right ventricle with sub...
# 6         0.001832  BC41.Z Acquired ventricular abnormality, unspe...
# 7         0.001519  LA87.43 Atrioventricular septal defect with co...
# 8         0.001490  KA82.0 Intraventricular nontraumatic haemorrha...
# 9         0.001394  LA87.42 Atrioventricular septal defect with co...
# Diagnosis: Diarrhea
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII     R19.4
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...           XI     K52.9
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...           XI     K59.1
# 3  http://id.who.int/icd/release/11/2024-01/mms/5...        XVIII     R19.4
# 4  http://id.who.int/icd/release/11/2024-01/mms/7...           XI     K90.9
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...          XVI     P78.3
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...            I     A02.0
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII       R53
# 8  http://id.who.int/icd/release/11/2024-01/mms/2...            I     A00.9
# 9  http://id.who.int/icd/release/11/2024-01/mms/4...        XVIII       R11
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0                              Change in bowel habit            21    ME05.1
# 1  Noninfective gastroenteritis and colitis, unsp...            13    DA90.0
# 2                               Functional diarrhoea            13    DD91.2
# 3                              Change in bowel habit            21    ME05.0
# 4              Intestinal malabsorption, unspecified            13   DA96.05
# 5                    Noninfective neonatal diarrhoea            19      KB8C
# 6                               Salmonella enteritis             1    1A09.0
# 7                                Malaise and fatigue            21      MG25
# 8                               Cholera, unspecified             1      1A00
# 9                                Nausea and vomiting            21    MD90.1
#
#                          icd11Title
# 0                         Diarrhoea
# 1               Syndromic diarrhoea
# 2              Functional diarrhoea
# 3                      Constipation
# 4                Intestinal failure
# 5  Noninfectious neonatal diarrhoea
# 6              Salmonella enteritis
# 7                       Feeling ill
# 8                           Cholera
# 9                          Vomiting
#    relevance_score                                         ranked_doc
# 0         0.036016                                   ME05.1 Diarrhoea
# 1         0.034750                13 Diseases of the digestive system
# 2         0.019271  DA94.3 Enteritis or ulcer of small intestine d...
# 3         0.018761  ME0Y Other specified symptoms related to the l...
# 4         0.014672  DA94.30 Enteritis or ulcer of small intestine ...
# 5         0.012576                    nan Diseases of small intestine
# 6         0.011508  ME4Y Other specified symptoms, signs or clinic...
# 7         0.011029  DA94.31 Enteritis or ulcer of small intestine ...
# 8         0.009559  DA94.32 Enteritis or ulcer of small intestine ...
# 9         0.008916                    nan Diseases of large intestine
# Diagnosis: Fever
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/9...            I     A68.9
# 1  http://id.who.int/icd/release/11/2024-01/mms/2...            I     A75.9
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...            I     A01.0
# 3  http://id.who.int/icd/release/11/2024-01/mms/9...            I     A68.9
# 4  http://id.who.int/icd/release/11/2024-01/mms/3...            I     A95.9
# 5  http://id.who.int/icd/release/11/2024-01/mms/6...          XVI   P80-P83
# 6  http://id.who.int/icd/release/11/2024-01/mms/9...        XVIII       R50
# 7  http://id.who.int/icd/release/11/2024-01/mms/2...            I       A78
# 8  http://id.who.int/icd/release/11/2024-01/mms/2...            I   A92-A99
# 9  http://id.who.int/icd/release/11/2024-01/mms/1...            I     A79.0
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0                       Relapsing fever, unspecified             1      1C1J
# 1                          Typhus fever, unspecified             1      1C30
# 2                                      Typhoid fever             1      1A07
# 3                       Relapsing fever, unspecified             1    1C1J.Z
# 4                          Yellow fever, unspecified             1      1D47
# 5  Conditions involving the integument and temper...            19      KD11
# 6                  Fever of other and unknown origin            21      MG26
# 7                                            Q fever             1      1C33
# 8  Arthropod-borne viral fevers and viral haemorr...             1      1D4E
# 9                                       Trench fever             1    1C11.1
#
#                                     icd11Title
# 0                              Relapsing fever
# 1                                 Typhus fever
# 2                                Typhoid fever
# 3                 Relapsing fever, unspecified
# 4                                 Yellow fever
# 5                             Fever of newborn
# 6             Fever of other or unknown origin
# 7                                      Q fever
# 8  Severe fever with thrombocytopenia syndrome
# 9                                 Trench fever
#    relevance_score                                         ranked_doc
# 0         0.003992           1F00.00 Herpes simplex infection of skin
# 1         0.002981  1F57.1 Meningoencephalitis due to Toxoplasma g...
# 2         0.002378  1F42.Y Malaria due to Plasmodium malariae with...
# 3         0.002243  1F41.0 Plasmodium vivax malaria with rupture o...
# 4         0.002234  8A01.14 Chorea due to infectious or para-infec...
# 5         0.002208   1F00.21 Encephalitis due to herpes simplex virus
# 6         0.001934  AA0Y Other specified infectious diseases of ex...
# 7         0.001868  1C31.0 Spotted fever due to Rickettsia rickettsii
# 8         0.001768                     1F00 Herpes simplex infections
# 9         0.001668                            1D48 Zika virus disease
# Diagnosis: Gaze paresis
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...          VII       H51
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...          VII       H51
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...          VII       H51
# 3  http://id.who.int/icd/release/11/2024-01/mms/3...          VII       H55
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...          VII     H52.5
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...          VII       H51
# 6  http://id.who.int/icd/release/11/2024-01/mms/1...          VII     H51.0
# 7  http://id.who.int/icd/release/11/2024-01/mms/4...          VII       H51
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...          VII     H51.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/2...          VII     H51.0
#
#                                     icd10Title  icd11Chapter icd11Code  \
# 0        Other disorders of binocular movement             9    9C83.1
# 1        Other disorders of binocular movement             9   9C83.1Y
# 2        Other disorders of binocular movement             9   9C83.1Z
# 3  Nystagmus and other irregular eye movements             9    9C84.4
# 4                   Disorders of accommodation             9    9D01.1
# 5        Other disorders of binocular movement             9   9C83.12
# 6                      Palsy of conjugate gaze             9    9C83.0
# 7        Other disorders of binocular movement             9   9C83.11
# 8                      Palsy of conjugate gaze             9   9C83.00
# 9                      Palsy of conjugate gaze             9   9C83.01
#
#                                 icd11Title
# 0                  Spasm of conjugate gaze
# 1  Other specified spasm of conjugate gaze
# 2     Spasm of conjugate gaze, unspecified
# 3                    Gaze-evoked nystagmus
# 4                 Paresis of accommodation
# 5                  Downward gaze deviation
# 6                  Palsy of conjugate gaze
# 7                    Upward gaze deviation
# 8                    Horizontal gaze palsy
# 9                      Vertical gaze palsy
#    relevance_score                                         ranked_doc
# 0         0.000929       9C83.0Z Palsy of conjugate gaze, unspecified
# 1         0.000904       9C83.1Z Spasm of conjugate gaze, unspecified
# 2         0.000773                      9C83.00 Horizontal gaze palsy
# 3         0.000654                     9C83.0 Palsy of conjugate gaze
# 4         0.000515  9C83.6Y Other specified anomalies of divergenc...
# 5         0.000507                        9C83.01 Vertical gaze palsy
# 6         0.000462                     9C83.1 Spasm of conjugate gaze
# 7         0.000442                9A03.23 Spastic ectropion of eyelid
# 8         0.000439                9A03.13 Spastic entropion of eyelid
# 9         0.000386      9A04.1 Madarosis of eyelid or periocular area
# Diagnosis: Subdural effusion
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...            X       J90
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...         XIII     M25.4
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...         XIII     M25.4
# 3  http://id.who.int/icd/release/11/2024-01/mms/1...         XIII     M25.4
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...           VI   G00-G09
# 5  http://id.who.int/icd/release/11/2024-01/mms/6...           VI   G00-G09
# 6  http://id.who.int/icd/release/11/2024-01/mms/2...         VIII       H92
# 7  http://id.who.int/icd/release/11/2024-01/mms/1...           VI   G00-G09
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...         XIII     M25.0
# 9  http://id.who.int/icd/release/11/2024-01/mms/2...           VI        VI
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0         Pleural effusion, not elsewhere classified            12      CB27
# 1                                  Effusion of joint            15      FA36
# 2                                  Effusion of joint            15    FA36.Z
# 3                                  Effusion of joint            15    FA36.Y
# 4  Inflammatory diseases of the central nervous s...             1    1D05.1
# 5  Inflammatory diseases of the central nervous s...             1    1D03.1
# 6                        Otalgia and effusion of ear            10      AB70
# 7  Inflammatory diseases of the central nervous s...             1    1D04.3
# 8                                      Haemarthrosis            15    FA36.0
# 9                     Diseases of the nervous system             8      8D6Z
#
#                                           icd11Title
# 0                                   Pleural effusion
# 1                                  Effusion of joint
# 2                     Effusion of joint, unspecified
# 3                  Other specified effusion of joint
# 4                           Subdural infectious cyst
# 5                       Intraspinal subdural abscess
# 6                         Otalgia or effusion of ear
# 7                     Intraspinal subdural granuloma
# 8                 Effusion of joint containing blood
# 9  Disorders of cerebrospinal fluid pressure or f...
#    relevance_score                                         ranked_doc
# 0         0.123155        ME93.1 Subluxation stenosis of neural canal
# 1         0.108378  NA07.6Z Traumatic subdural haemorrhage, unspec...
# 2         0.054099                       NA0D.11 Subluxation of tooth
# 3         0.038756                NA06.85 Avulsion of eye, unilateral
# 4         0.035344       NA07.60 Acute traumatic subdural haemorrhage
# 5         0.033780     NA07.61 Chronic traumatic subdural haemorrhage
# 6         0.025131              NA07.6 Traumatic subdural haemorrhage
# 7         0.012920                    1D05.1 Subdural infectious cyst
# 8         0.011332   KA40.00 Subdural haemorrhage due to birth injury
# 9         0.010052  KA82.7 Subdural nontraumatic haemorrhage of fe...
# Diagnosis: Laryngeal stridor
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/1...        XVIII     R06.1
# 1  http://id.who.int/icd/release/11/2024-01/mms/1...            X     J38.4
# 2  http://id.who.int/icd/release/11/2024-01/mms/1...            X     J38.5
# 3  http://id.who.int/icd/release/11/2024-01/mms/9...            X     J38.0
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...          XXI     Z96.3
# 5  http://id.who.int/icd/release/11/2024-01/mms/1...         XVII     Q31.2
# 6  http://id.who.int/icd/release/11/2024-01/mms/8...            X     J38.6
# 7  http://id.who.int/icd/release/11/2024-01/mms/3...         XVII     Q31.3
# 8  http://id.who.int/icd/release/11/2024-01/mms/1...            I     A36.2
# 9  http://id.who.int/icd/release/11/2024-01/mms/1...            X     J05.0
#
#                              icd10Title  icd11Chapter icd11Code  \
# 0                               Stridor            21    MD11.B
# 1                      Oedema of larynx            12    CA0H.3
# 2                       Laryngeal spasm            12    CA0H.4
# 3   Paralysis of vocal cords and larynx            12    CA0H.0
# 4         Presence of artificial larynx            24    QB51.4
# 5                  Laryngeal hypoplasia            20    LA71.2
# 6                    Stenosis of larynx            12    CA0H.5
# 7                           Laryngocele            20    LA71.1
# 8                  Laryngeal diphtheria             1    1C17.2
# 9  Acute obstructive laryngitis [croup]            12    CA06.0
#
#                            icd11Title
# 0                             Stridor
# 1                    Oedema of larynx
# 2                     Laryngeal spasm
# 3  Paralysis of vocal cords or larynx
# 4       Presence of artificial larynx
# 5                Laryngeal hypoplasia
# 6                  Stenosis of larynx
# 7                         Laryngocele
# 8                Laryngeal diphtheria
# 9        Acute obstructive laryngitis
#    relevance_score                                         ranked_doc
# 0         0.148170                             CA0H.4 Laryngeal spasm
# 1         0.037538   2C23.4 Malignant neoplasm of laryngeal cartilage
# 2         0.026456                                     MD11.B Stridor
# 3         0.017986          NA23.5 Strain or sprain of thyroid region
# 4         0.013849                   NA04.3 Injury of trochlear nerve
# 5         0.009413                          CA0H.5 Stenosis of larynx
# 6         0.009413                CA05 Acute laryngitis or tracheitis
# 7         0.006824               LA72 Laryngotracheooesophageal cleft
# 8         0.004664  PK92.2 Otorhinolaryngological devices associat...
# 9         0.004628  PK92.1 Otorhinolaryngological devices associat...
# Diagnosis: Allergic skin lesions
#                          Linearization (release) URI icd10Chapter icd10Code  \
# 0  http://id.who.int/icd/release/11/2024-01/mms/2...          XII       L23
# 1  http://id.who.int/icd/release/11/2024-01/mms/4...          XII     L98.9
# 2  http://id.who.int/icd/release/11/2024-01/mms/2...          XII     L98.9
# 3  http://id.who.int/icd/release/11/2024-01/mms/7...          XII     L85.9
# 4  http://id.who.int/icd/release/11/2024-01/mms/1...          XIX     T78.4
# 5  http://id.who.int/icd/release/11/2024-01/mms/4...          XII     L98.9
# 6  http://id.who.int/icd/release/11/2024-01/mms/3...          XII     L81.9
# 7  http://id.who.int/icd/release/11/2024-01/mms/9...           IV   E10-E14
# 8  http://id.who.int/icd/release/11/2024-01/mms/2...          XII       L23
# 9  http://id.who.int/icd/release/11/2024-01/mms/6...          XII     L98.8
#
#                                           icd10Title  icd11Chapter icd11Code  \
# 0                        Allergic contact dermatitis            14      EK00
# 1  Disorder of skin and subcutaneous tissue, unsp...            21    ME60.Z
# 2  Disorder of skin and subcutaneous tissue, unsp...            21    ME60.0
# 3                  Epidermal thickening, unspecified            14      ED53
# 4                               Allergy, unspecified             4      4A82
# 5  Disorder of skin and subcutaneous tissue, unsp...            21      ME60
# 6              Disorder of pigmentation, unspecified            21    ME60.1
# 7                                  Diabetes mellitus            14    EB90.0
# 8                        Allergic contact dermatitis            14    EK00.Z
# 9  Other specified disorders of skin and subcutan...            14      EG9Z
#
#                                           icd11Title
# 0                        Allergic contact dermatitis
# 1                  Skin lesion of unspecified nature
# 2                    Skin lesion of uncertain nature
# 3                                       Skin peeling
# 4  Allergic or hypersensitivity disorders involvi...
# 5     Skin lesion of uncertain or unspecified nature
# 6          Pigmented skin lesion of uncertain nature
# 7                              Diabetic skin lesions
# 8           Allergic contact dermatitis, unspecified
# 9  Skin disorders involving certain specific body...
#    relevance_score                                         ranked_doc
# 0         0.042088  EK00.7 Allergic contact dermatitis due to alle...
# 1         0.035013  4A82 Allergic or hypersensitivity disorders in...
# 2         0.025663  EK00.5 Allergic contact dermatitis due to indu...
# 3         0.022371  EK00.6 Allergic contact dermatitis due to meta...
# 4         0.012723  EK00.8 Allergic contact dermatitis due to plas...
# 5         0.009232  4A85.22 Allergic contact dermatitis due to foo...
# 6         0.008678                   EK00 Allergic contact dermatitis
# 7         0.007519  EK00.3 Allergic contact dermatitis due to food...
# 8         0.007261  EK00.0 Allergic contact dermatitis due to clot...
# 9         0.007205    EK00.Z Allergic contact dermatitis, unspecified

# %%
def search_list_of_diagnosis(diagnosis):
    results = []
    for d in diagnosis:
        results.append(vectorstore.similarity_search_with_score(d, k=5))
    return results

# search for the most similar code to the diagnosis
# diagnosis = ["diagnosis of diabetes"]

# search vectorstore
results = search_list_of_diagnosis(list_of_diagnosis)

# %%
results
# Out:
# [[(Document(page_content='Sarcocystosis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/261748740', 'icd10Chapter': 'I', 'icd10Code': 'A07.8', 'icd10Title': 'Other specified protozoal intestinal diseases', 'icd11Chapter': 1, 'icd11Code': '1A34', 'icd11Title': 'Sarcocystosis'}),
#    0.7782320976257324),
#   (Document(page_content='Sarcocystosis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/261748740', 'icd10Chapter': 'I', 'icd10Code': 'A07.8', 'icd10Title': 'Other specified protozoal intestinal diseases', 'icd11Chapter': 1, 'icd11Code': '1A34', 'icd11Title': 'Sarcocystosis'}),
#    0.7782320976257324),
#   (Document(page_content='Other specified cystoisosporiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/other', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Y', 'icd11Title': 'Other specified cystoisosporiasis'}),
#    0.7857500314712524),
#   (Document(page_content='Other specified cystoisosporiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/other', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Y', 'icd11Title': 'Other specified cystoisosporiasis'}),
#    0.7857500314712524),
#   (Document(page_content='Cystoisosporiasis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Z', 'icd11Title': 'Cystoisosporiasis, unspecified'}),
#    0.8041753768920898)],
#  [(Document(page_content='Late congenital neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/282073961', 'icd10Chapter': 'I', 'icd10Code': 'A50.4', 'icd10Title': 'Late congenital neurosyphilis [juvenile neurosyphilis]', 'icd11Chapter': 1, 'icd11Code': '1A60.3', 'icd11Title': 'Late congenital neurosyphilis'}),
#    0.724565863609314),
#   (Document(page_content='Late congenital neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/282073961', 'icd10Chapter': 'I', 'icd10Code': 'A50.4', 'icd10Title': 'Late congenital neurosyphilis [juvenile neurosyphilis]', 'icd11Chapter': 1, 'icd11Code': '1A60.3', 'icd11Title': 'Late congenital neurosyphilis'}),
#    0.724565863609314),
#   (Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.737964391708374),
#   (Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.737964391708374),
#   (Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.7399327158927917)],
#  [(Document(page_content='Secondary syphilis of skin or mucous membranes', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2143699068', 'icd10Chapter': 'I', 'icd10Code': 'A51.3', 'icd10Title': 'Secondary syphilis of skin and mucous membranes', 'icd11Chapter': 1, 'icd11Code': '1A61.3', 'icd11Title': 'Secondary syphilis of skin or mucous membranes'}),
#    0.653418242931366),
#   (Document(page_content='Secondary syphilis of skin or mucous membranes', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2143699068', 'icd10Chapter': 'I', 'icd10Code': 'A51.3', 'icd10Title': 'Secondary syphilis of skin and mucous membranes', 'icd11Chapter': 1, 'icd11Code': '1A61.3', 'icd11Title': 'Secondary syphilis of skin or mucous membranes'}),
#    0.653418242931366),
#   (Document(page_content='Cystoisosporiasis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Z', 'icd11Title': 'Cystoisosporiasis, unspecified'}),
#    0.6863546967506409),
#   (Document(page_content='Cystoisosporiasis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Z', 'icd11Title': 'Cystoisosporiasis, unspecified'}),
#    0.6863546967506409),
#   (Document(page_content='Early congenital syphilis, symptomatic', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/395565060', 'icd10Chapter': 'I', 'icd10Code': 'A50.0', 'icd10Title': 'Early congenital syphilis, symptomatic', 'icd11Chapter': 1, 'icd11Code': '1A60.0', 'icd11Title': 'Early congenital syphilis, symptomatic'}),
#    0.6928917169570923)],
#  [(Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7306142449378967),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7306142449378967),
#   (Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.7621495127677917),
#   (Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.7621495127677917),
#   (Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.7658979296684265)],
#  [(Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.6142646074295044),
#   (Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.6142646074295044),
#   (Document(page_content='Foodborne staphylococcal intoxication', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1642556936', 'icd10Chapter': 'I', 'icd10Code': 'A05.0', 'icd10Title': 'Foodborne staphylococcal intoxication', 'icd11Chapter': 1, 'icd11Code': '1A10', 'icd11Title': 'Foodborne staphylococcal intoxication'}),
#    0.6831670999526978),
#   (Document(page_content='Foodborne staphylococcal intoxication', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1642556936', 'icd10Chapter': 'I', 'icd10Code': 'A05.0', 'icd10Title': 'Foodborne staphylococcal intoxication', 'icd11Chapter': 1, 'icd11Code': '1A10', 'icd11Title': 'Foodborne staphylococcal intoxication'}),
#    0.6831670999526978),
#   (Document(page_content='Bacterial foodborne intoxications', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1834648119', 'icd10Chapter': 'I', 'icd10Code': 'A05.9', 'icd10Title': 'Bacterial foodborne intoxication, unspecified', 'icd11Chapter': 1, 'icd11Title': 'Bacterial foodborne intoxications'}),
#    0.7005018591880798)],
#  [(Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7350702881813049),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7350702881813049),
#   (Document(page_content='Symptomatic late syphilis of other sites', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1883423833', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.2', 'icd11Title': 'Symptomatic late syphilis of other sites'}),
#    0.7418181896209717),
#   (Document(page_content='Symptomatic late syphilis of other sites', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1883423833', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.2', 'icd11Title': 'Symptomatic late syphilis of other sites'}),
#    0.7418181896209717),
#   (Document(page_content='Asymptomatic neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/453651926', 'icd10Chapter': 'I', 'icd10Code': 'A52.2', 'icd10Title': 'Asymptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.00', 'icd11Title': 'Asymptomatic neurosyphilis'}),
#    0.7516783475875854)],
#  [(Document(page_content='Amoebiasis of other specified sites', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1777228366/other', 'icd10Chapter': 'I', 'icd10Code': 'A06.9', 'icd10Title': 'Amoebiasis, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A36.1Y', 'icd11Title': 'Amoebiasis of other specified sites'}),
#    0.7861313223838806),
#   (Document(page_content='Amoebiasis of other specified sites', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1777228366/other', 'icd10Chapter': 'I', 'icd10Code': 'A06.9', 'icd10Title': 'Amoebiasis, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A36.1Y', 'icd11Title': 'Amoebiasis of other specified sites'}),
#    0.7861313223838806),
#   (Document(page_content='Symptomatic late syphilis of other sites', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1883423833', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.2', 'icd11Title': 'Symptomatic late syphilis of other sites'}),
#    0.8183777928352356),
#   (Document(page_content='Symptomatic late syphilis of other sites', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1883423833', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.2', 'icd11Title': 'Symptomatic late syphilis of other sites'}),
#    0.8183777928352356),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.8391205668449402)],
#  [(Document(page_content='Paratyphoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1780040028', 'icd10Chapter': 'I', 'icd10Code': 'A01', 'icd10Title': 'Typhoid and paratyphoid fevers', 'icd11Chapter': 1, 'icd11Code': '1A08', 'icd11Title': 'Paratyphoid fever'}),
#    0.6855170726776123),
#   (Document(page_content='Paratyphoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1780040028', 'icd10Chapter': 'I', 'icd10Code': 'A01', 'icd10Title': 'Typhoid and paratyphoid fevers', 'icd11Chapter': 1, 'icd11Code': '1A08', 'icd11Title': 'Paratyphoid fever'}),
#    0.6855170726776123),
#   (Document(page_content='Syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/455894495', 'icd10Chapter': 'I', 'icd10Code': 'A50-A64', 'icd10Title': 'Infections with a predominantly sexual mode of transmission', 'icd11Chapter': 1, 'icd11Title': 'Syphilis'}),
#    0.6985427737236023),
#   (Document(page_content='Syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/455894495', 'icd10Chapter': 'I', 'icd10Code': 'A50-A64', 'icd10Title': 'Infections with a predominantly sexual mode of transmission', 'icd11Chapter': 1, 'icd11Title': 'Syphilis'}),
#    0.6985427737236023),
#   (Document(page_content='Typhoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1528414070', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07', 'icd11Title': 'Typhoid fever'}),
#    0.714020848274231)],
#  [(Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.7031501531600952),
#   (Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.7031501531600952),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7164407968521118),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7164407968521118),
#   (Document(page_content='Enteroinvasive Escherichia coli infection', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1828273122', 'icd10Chapter': 'I', 'icd10Code': 'A04.2', 'icd10Title': 'Enteroinvasive Escherichia coli infection', 'icd11Chapter': 1, 'icd11Code': '1A03.2', 'icd11Title': 'Enteroinvasive Escherichia coli infection'}),
#    0.7440485954284668)],
#  [(Document(page_content='Bacterial foodborne intoxications', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1834648119', 'icd10Chapter': 'I', 'icd10Code': 'A05.9', 'icd10Title': 'Bacterial foodborne intoxication, unspecified', 'icd11Chapter': 1, 'icd11Title': 'Bacterial foodborne intoxications'}),
#    0.8887041807174683),
#   (Document(page_content='Bacterial foodborne intoxications', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1834648119', 'icd10Chapter': 'I', 'icd10Code': 'A05.9', 'icd10Title': 'Bacterial foodborne intoxication, unspecified', 'icd11Chapter': 1, 'icd11Title': 'Bacterial foodborne intoxications'}),
#    0.8887041807174683),
#   (Document(page_content='Foodborne staphylococcal intoxication', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1642556936', 'icd10Chapter': 'I', 'icd10Code': 'A05.0', 'icd10Title': 'Foodborne staphylococcal intoxication', 'icd11Chapter': 1, 'icd11Code': '1A10', 'icd11Title': 'Foodborne staphylococcal intoxication'}),
#    0.889488697052002),
#   (Document(page_content='Foodborne staphylococcal intoxication', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1642556936', 'icd10Chapter': 'I', 'icd10Code': 'A05.0', 'icd10Title': 'Foodborne staphylococcal intoxication', 'icd11Chapter': 1, 'icd11Code': '1A10', 'icd11Title': 'Foodborne staphylococcal intoxication'}),
#    0.889488697052002),
#   (Document(page_content='Foodborne Clostridium perfringens intoxication', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1879176035', 'icd10Chapter': 'I', 'icd10Code': 'A05.2', 'icd10Title': 'Foodborne Clostridium perfringens [Clostridium welchii] intoxication', 'icd11Chapter': 1, 'icd11Code': '1A12', 'icd11Title': 'Foodborne Clostridium perfringens intoxication'}),
#    0.9037919044494629)],
#  [(Document(page_content='Amoebic lung abscess', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/40419529', 'icd10Chapter': 'I', 'icd10Code': 'A06.5', 'icd10Title': 'Amoebic lung abscess', 'icd11Chapter': 1, 'icd11Code': '1A36.11', 'icd11Title': 'Amoebic lung abscess'}),
#    0.7001762986183167),
#   (Document(page_content='Amoebic lung abscess', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/40419529', 'icd10Chapter': 'I', 'icd10Code': 'A06.5', 'icd10Title': 'Amoebic lung abscess', 'icd11Chapter': 1, 'icd11Code': '1A36.11', 'icd11Title': 'Amoebic lung abscess'}),
#    0.7001762986183167),
#   (Document(page_content='Typhoid peritonitis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/364534567', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07.0', 'icd11Title': 'Typhoid peritonitis'}),
#    0.7101843953132629),
#   (Document(page_content='Typhoid peritonitis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/364534567', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07.0', 'icd11Title': 'Typhoid peritonitis'}),
#    0.7101843953132629),
#   (Document(page_content='Acute amoebiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1616956984', 'icd10Chapter': 'I', 'icd10Code': 'A06.0', 'icd10Title': 'Acute amoebic dysentery', 'icd11Chapter': 1, 'icd11Code': '1A36.00', 'icd11Title': 'Acute amoebiasis'}),
#    0.7510915398597717)],
#  [(Document(page_content='Cutaneous amoebiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/328097188', 'icd10Chapter': 'I', 'icd10Code': 'A06.7', 'icd10Title': 'Cutaneous amoebiasis', 'icd11Chapter': 1, 'icd11Code': '1A36.12', 'icd11Title': 'Cutaneous amoebiasis'}),
#    0.5668157935142517),
#   (Document(page_content='Cutaneous amoebiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/328097188', 'icd10Chapter': 'I', 'icd10Code': 'A06.7', 'icd10Title': 'Cutaneous amoebiasis', 'icd11Chapter': 1, 'icd11Code': '1A36.12', 'icd11Title': 'Cutaneous amoebiasis'}),
#    0.5668157935142517),
#   (Document(page_content='Secondary syphilis of skin or mucous membranes', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2143699068', 'icd10Chapter': 'I', 'icd10Code': 'A51.3', 'icd10Title': 'Secondary syphilis of skin and mucous membranes', 'icd11Chapter': 1, 'icd11Code': '1A61.3', 'icd11Title': 'Secondary syphilis of skin or mucous membranes'}),
#    0.643098771572113),
#   (Document(page_content='Secondary syphilis of skin or mucous membranes', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2143699068', 'icd10Chapter': 'I', 'icd10Code': 'A51.3', 'icd10Title': 'Secondary syphilis of skin and mucous membranes', 'icd11Chapter': 1, 'icd11Code': '1A61.3', 'icd11Title': 'Secondary syphilis of skin or mucous membranes'}),
#    0.643098771572113),
#   (Document(page_content='Cystoisosporiasis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Z', 'icd11Title': 'Cystoisosporiasis, unspecified'}),
#    0.6900544166564941)],
#  [(Document(page_content='Salmonella enteritis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1520312138', 'icd10Chapter': 'I', 'icd10Code': 'A02.0', 'icd10Title': 'Salmonella enteritis', 'icd11Chapter': 1, 'icd11Code': '1A09.0', 'icd11Title': 'Salmonella enteritis'}),
#    0.47631874680519104),
#   (Document(page_content='Salmonella enteritis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1520312138', 'icd10Chapter': 'I', 'icd10Code': 'A02.0', 'icd10Title': 'Salmonella enteritis', 'icd11Chapter': 1, 'icd11Code': '1A09.0', 'icd11Title': 'Salmonella enteritis'}),
#    0.47631874680519104),
#   (Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.4917639493942261),
#   (Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.4917639493942261),
#   (Document(page_content='Intestinal infections due to Escherichia coli, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/344162786/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A04', 'icd10Title': 'Other bacterial intestinal infections', 'icd11Chapter': 1, 'icd11Code': '1A03.Z', 'icd11Title': 'Intestinal infections due to Escherichia coli, unspecified'}),
#    0.5330432653427124)],
#  [(Document(page_content='Typhoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1528414070', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07', 'icd11Title': 'Typhoid fever'}),
#    0.3709713816642761),
#   (Document(page_content='Typhoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1528414070', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07', 'icd11Title': 'Typhoid fever'}),
#    0.3709713816642761),
#   (Document(page_content='Paratyphoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1780040028', 'icd10Chapter': 'I', 'icd10Code': 'A01', 'icd10Title': 'Typhoid and paratyphoid fevers', 'icd11Chapter': 1, 'icd11Code': '1A08', 'icd11Title': 'Paratyphoid fever'}),
#    0.4562807083129883),
#   (Document(page_content='Paratyphoid fever', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1780040028', 'icd10Chapter': 'I', 'icd10Code': 'A01', 'icd10Title': 'Typhoid and paratyphoid fevers', 'icd11Chapter': 1, 'icd11Code': '1A08', 'icd11Title': 'Paratyphoid fever'}),
#    0.4562807083129883),
#   (Document(page_content='Typhoid fever, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1528414070/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07.Z', 'icd11Title': 'Typhoid fever, unspecified'}),
#    0.4884783923625946)],
#  [(Document(page_content='Cardiovascular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/183283901', 'icd10Chapter': 'I', 'icd10Code': 'A52.0', 'icd10Title': 'Cardiovascular syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.1', 'icd11Title': 'Cardiovascular late syphilis'}),
#    0.6856302618980408),
#   (Document(page_content='Cardiovascular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/183283901', 'icd10Chapter': 'I', 'icd10Code': 'A52.0', 'icd10Title': 'Cardiovascular syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.1', 'icd11Title': 'Cardiovascular late syphilis'}),
#    0.6856302618980408),
#   (Document(page_content='Enteroinvasive Escherichia coli infection', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1828273122', 'icd10Chapter': 'I', 'icd10Code': 'A04.2', 'icd10Title': 'Enteroinvasive Escherichia coli infection', 'icd11Chapter': 1, 'icd11Code': '1A03.2', 'icd11Title': 'Enteroinvasive Escherichia coli infection'}),
#    0.7730088829994202),
#   (Document(page_content='Enteroinvasive Escherichia coli infection', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1828273122', 'icd10Chapter': 'I', 'icd10Code': 'A04.2', 'icd10Title': 'Enteroinvasive Escherichia coli infection', 'icd11Chapter': 1, 'icd11Code': '1A03.2', 'icd11Title': 'Enteroinvasive Escherichia coli infection'}),
#    0.7730088829994202),
#   (Document(page_content='Cholera', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/257068234', 'icd10Chapter': 'I', 'icd10Code': 'A00.9', 'icd10Title': 'Cholera, unspecified', 'icd11Chapter': 1, 'icd11Code': '1A00', 'icd11Title': 'Cholera'}),
#    0.7738037705421448)],
#  [(Document(page_content='Cardiovascular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/183283901', 'icd10Chapter': 'I', 'icd10Code': 'A52.0', 'icd10Title': 'Cardiovascular syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.1', 'icd11Title': 'Cardiovascular late syphilis'}),
#    0.8289084434509277),
#   (Document(page_content='Cardiovascular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/183283901', 'icd10Chapter': 'I', 'icd10Code': 'A52.0', 'icd10Title': 'Cardiovascular syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.1', 'icd11Title': 'Cardiovascular late syphilis'}),
#    0.8289084434509277),
#   (Document(page_content='Ocular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/551528014', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.20', 'icd11Title': 'Ocular late syphilis'}),
#    0.851448118686676),
#   (Document(page_content='Ocular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/551528014', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.20', 'icd11Title': 'Ocular late syphilis'}),
#    0.851448118686676),
#   (Document(page_content='Late congenital syphilis, latent', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/20350466', 'icd10Chapter': 'I', 'icd10Code': 'A50.6', 'icd10Title': 'Late congenital syphilis, latent', 'icd11Chapter': 1, 'icd11Code': '1A60.5', 'icd11Title': 'Late congenital syphilis, latent'}),
#    0.8597840666770935)],
#  [(Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.8603638410568237),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.8603638410568237),
#   (Document(page_content='Acute amoebiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1616956984', 'icd10Chapter': 'I', 'icd10Code': 'A06.0', 'icd10Title': 'Acute amoebic dysentery', 'icd11Chapter': 1, 'icd11Code': '1A36.00', 'icd11Title': 'Acute amoebiasis'}),
#    0.869315505027771),
#   (Document(page_content='Acute amoebiasis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1616956984', 'icd10Chapter': 'I', 'icd10Code': 'A06.0', 'icd10Title': 'Acute amoebic dysentery', 'icd11Chapter': 1, 'icd11Code': '1A36.00', 'icd11Title': 'Acute amoebiasis'}),
#    0.869315505027771),
#   (Document(page_content='Latent early syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1768103550', 'icd10Chapter': 'I', 'icd10Code': 'A51.5', 'icd10Title': 'Early syphilis, latent', 'icd11Chapter': 1, 'icd11Code': '1A61.5', 'icd11Title': 'Latent early syphilis'}),
#    0.8768187761306763)],
#  [(Document(page_content='Amoeboma of intestine', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/349019849', 'icd10Chapter': 'I', 'icd10Code': 'A06.3', 'icd10Title': 'Amoeboma of intestine', 'icd11Chapter': 1, 'icd11Code': '1A36.01', 'icd11Title': 'Amoeboma of intestine'}),
#    0.7483292818069458),
#   (Document(page_content='Amoeboma of intestine', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/349019849', 'icd10Chapter': 'I', 'icd10Code': 'A06.3', 'icd10Title': 'Amoeboma of intestine', 'icd11Chapter': 1, 'icd11Code': '1A36.01', 'icd11Title': 'Amoeboma of intestine'}),
#    0.7483292818069458),
#   (Document(page_content='Late congenital neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/282073961', 'icd10Chapter': 'I', 'icd10Code': 'A50.4', 'icd10Title': 'Late congenital neurosyphilis [juvenile neurosyphilis]', 'icd11Chapter': 1, 'icd11Code': '1A60.3', 'icd11Title': 'Late congenital neurosyphilis'}),
#    0.8063464164733887),
#   (Document(page_content='Late congenital neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/282073961', 'icd10Chapter': 'I', 'icd10Code': 'A50.4', 'icd10Title': 'Late congenital neurosyphilis [juvenile neurosyphilis]', 'icd11Chapter': 1, 'icd11Code': '1A60.3', 'icd11Title': 'Late congenital neurosyphilis'}),
#    0.8063464164733887),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.8177767992019653)],
#  [(Document(page_content='Ocular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/551528014', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.20', 'icd11Title': 'Ocular late syphilis'}),
#    0.7004765272140503),
#   (Document(page_content='Ocular late syphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/551528014', 'icd10Chapter': 'I', 'icd10Code': 'A52.7', 'icd10Title': 'Other symptomatic late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.20', 'icd11Title': 'Ocular late syphilis'}),
#    0.7004765272140503),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7635376453399658),
#   (Document(page_content='Symptomatic late neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1873247529', 'icd10Chapter': 'I', 'icd10Code': 'A52.1', 'icd10Title': 'Symptomatic neurosyphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.01', 'icd11Title': 'Symptomatic late neurosyphilis'}),
#    0.7635376453399658),
#   (Document(page_content='Neurosyphilis', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0', 'icd11Title': 'Neurosyphilis'}),
#    0.7810194492340088)],
#  [(Document(page_content='Neurosyphilis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0Z', 'icd11Title': 'Neurosyphilis, unspecified'}),
#    0.7341353893280029),
#   (Document(page_content='Neurosyphilis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/2118246468/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A52', 'icd10Title': 'Late syphilis', 'icd11Chapter': 1, 'icd11Code': '1A62.0Z', 'icd11Title': 'Neurosyphilis, unspecified'}),
#    0.7341353893280029),
#   (Document(page_content='Cystoisosporiasis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Z', 'icd11Title': 'Cystoisosporiasis, unspecified'}),
#    0.7351991534233093),
#   (Document(page_content='Cystoisosporiasis, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/137713224/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A07.3', 'icd10Title': 'Isosporiasis', 'icd11Chapter': 1, 'icd11Code': '1A33.Z', 'icd11Title': 'Cystoisosporiasis, unspecified'}),
#    0.7351991534233093),
#   (Document(page_content='Typhoid fever, unspecified', metadata={'Linearization (release) URI': 'http://id.who.int/icd/release/11/2024-01/mms/1528414070/unspecified', 'icd10Chapter': 'I', 'icd10Code': 'A01.0', 'icd10Title': 'Typhoid fever', 'icd11Chapter': 1, 'icd11Code': '1A07.Z', 'icd11Title': 'Typhoid fever, unspecified'}),
#    0.7481076717376709)]]
